# %%
# xgboost для регрессии
from numpy import asarray
from numpy import mean
from numpy import std
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from src.drawing import show_forecast_test_plot, show_time_series_only, show_acf_pacf
from src.statistic import check_stationarity, make_diff_n_degree

# %%
ts = pd.read_csv('train.csv')
ts['Date'] = pd.to_datetime(ts['Date'])

# %%
def create_date_features(df):
    df['month'] = df.Date.dt.month
    df['day_of_month'] = df.Date.dt.day
    df['day_of_year'] = df.Date.dt.dayofyear
    # 1.1.2013 is Tuesday, so our starting point is the 2nd day of week
    df['day_of_week'] = df.Date.dt.dayofweek + 1
    df['year'] = df.Date.dt.year
    df["is_wknd"] = df.Date.dt.weekday // 4
    df['is_month_start'] = df.Date.dt.is_month_start.astype(int)
    df['is_month_end'] = df.Date.dt.is_month_end.astype(int)
    return df

ts = create_date_features(ts)

def lag_features(dataframe, lags):
    dataframe = dataframe.copy()
    for lag in lags:
        dataframe['lag_' + str(lag)] = dataframe['target_value'].transform(
            lambda x: x.shift(lag))
    return dataframe

ts = lag_features(ts, [1, 2, 3, 4, 5, 7, 10])

def roll_mean_features(dataframe, windows):
    dataframe = dataframe.copy()
    for window in windows:
        dataframe['mean_' + str(window)] = dataframe['target_value'].transform(lambda x:
                                                                               x.shift(1).rolling(window=window, min_periods=1, win_type="triang").mean())
    return dataframe
ts = roll_mean_features(ts, [1, 2, 7, 14, 30])

def ewm_features(dataframe, alphas, lags):
    dataframe = dataframe.copy()
    for alpha in alphas:
        for lag in lags:
            dataframe['ewm_alpha_' + str(alpha).replace(".", "") + "_lag_" + str(lag)] = \
                dataframe['target_value']. \
                    transform(lambda x: x.shift(lag).ewm(alpha=alpha).mean())
    return dataframe

alphas = [0.95, 0.9, 0.8, 0.7, 0.5]
lags = [1, 2, 3, 4, 5, 7, 10]
ts = ewm_features(ts, alphas, lags)
ts = pd.get_dummies(ts, columns=[ 'day_of_week', 'month'])

ts['target_value'] = np.log1p(ts["target_value"].values)

# %%
time = ts.Date
target = ts.target_value
TRAIN_SIZE = len(target) - 7
train, test = train_test_split(ts, train_size=TRAIN_SIZE, shuffle=False)

show_time_series_only(time, target)
test_values = target[TRAIN_SIZE:]
# Out:
# <div>                            <div id="8acaca79-1742-4310-8378-7e824e190fba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8acaca79-1742-4310-8378-7e824e190fba")) {                    Plotly.newPlot(                        "8acaca79-1742-4310-8378-7e824e190fba",                        [{"x":["2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-25T00:00:00","2021-12-26T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-09T00:00:00","2022-04-10T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-16T00:00:00","2022-04-17T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-23T00:00:00","2022-04-24T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-15T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-21T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05- ...

# %%
# def create_features(df, label=None):
#     """
#     Creates time series features from datetime index
#     """
#
#     df['date'] = df.Date
#     df['hour'] = df['date'].dt.hour
#     df['dayofweek'] = df['date'].dt.dayofweek
#     df['quarter'] = df['date'].dt.quarter
#     df['month'] = df['date'].dt.month
#     df['year'] = df['date'].dt.year
#     df['dayofyear'] = df['date'].dt.dayofyear
#     df['dayofmonth'] = df['date'].dt.day
#
#
#     X = df[['hour','dayofweek','quarter','month','year',
#            'dayofyear','dayofmonth']]
#     if label:
#         y = df[label]
#         return X, y
#     return X

X_train = train.drop(['Date', 'target_value'], axis=1)
y_train = train.target_value
X_test =test.drop(['Date', 'target_value'], axis=1)
y_test = test.target_value

# %%
reg = XGBRegressor(n_estimators=100)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=True) # Change verbose to True if you want to see it train
'''
XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
       colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
       importance_type='gain', interaction_constraints=None,
       learning_rate=0.300000012, max_delta_step=0, max_depth=6,
       min_child_weight=1, missing=nan, monotone_constraints=None,
       n_estimators=100, n_jobs=0, num_parallel_tree=1,
       objective='reg:squarederror', random_state=0, reg_alpha=0,
       reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
       validate_parameters=False, verbosity=None)
'''
# Out:
# [0]	validation_0-rmse:4.97036	validation_1-rmse:4.49295
# [1]	validation_0-rmse:3.48969	validation_1-rmse:3.10489
# [2]	validation_0-rmse:2.45110	validation_1-rmse:2.14697
# [3]	validation_0-rmse:1.72262	validation_1-rmse:1.46618
# [4]	validation_0-rmse:1.21146	validation_1-rmse:1.02567
# [5]	validation_0-rmse:0.85272	validation_1-rmse:0.70842
# [6]	validation_0-rmse:0.60130	validation_1-rmse:0.49686
# [7]	validation_0-rmse:0.42467	validation_1-rmse:0.34540
# [8]	validation_0-rmse:0.30064	validation_1-rmse:0.24227
# [9]	validation_0-rmse:0.21396	validation_1-rmse:0.16576
# [10]	validation_0-rmse:0.15310	validation_1-rmse:0.11351
# [11]	validation_0-rmse:0.11074	validation_1-rmse:0.07962
# [12]	validation_0-rmse:0.08095	validation_1-rmse:0.05153
# [13]	validation_0-rmse:0.06040	validation_1-rmse:0.04338
# [14]	validation_0-rmse:0.04572	validation_1-rmse:0.03438
# [15]	validation_0-rmse:0.03597	validation_1-rmse:0.03329
# [16]	validation_0-rmse:0.02952	validation_1-rmse:0.03566
# [17]	validation_0-rmse:0.02494	validation_1-rmse:0.03713
# [18]	validation_0-rmse:0.02161	validation_1-rmse:0.03837
# [19]	validation_0-rmse:0.01920	validation_1-rmse:0.03926
# [20]	validation_0-rmse:0.01698	validation_1-rmse:0.04027
# [21]	validation_0-rmse:0.01517	validation_1-rmse:0.04075
# [22]	validation_0-rmse:0.01412	validation_1-rmse:0.04122
# [23]	validation_0-rmse:0.01272	validation_1-rmse:0.04113
# [24]	validation_0-rmse:0.01209	validation_1-rmse:0.04238
# [25]	validation_0-rmse:0.01146	validation_1-rmse:0.04254
# [26]	validation_0-rmse:0.01101	validation_1-rmse:0.04340
# [27]	validation_0-rmse:0.01008	validation_1-rmse:0.04358
# [28]	validation_0-rmse:0.00950	validation_1-rmse:0.04367
# [29]	validation_0-rmse:0.00917	validation_1-rmse:0.04339
# [30]	validation_0-rmse:0.00808	validation_1-rmse:0.04337
# [31]	validation_0-rmse:0.00748	validation_1-rmse:0.04344
# [32]	validation_0-rmse:0.00716	validation_1-rmse:0.04395
# [33]	validation_0-rmse:0.00649	validation_1-rmse:0.04410
# [34]	validation_0-rmse:0.00604	validation_1-rmse:0.04444
# [35]	validation_0-rmse:0.00552	validation_1-rmse:0.04439
# [36]	validation_0-rmse:0.00532	validation_1-rmse:0.04412
# [37]	validation_0-rmse:0.00492	validation_1-rmse:0.04416
# [38]	validation_0-rmse:0.00454	validation_1-rmse:0.04458
# [39]	validation_0-rmse:0.00428	validation_1-rmse:0.04457
# [40]	validation_0-rmse:0.00409	validation_1-rmse:0.04484
# [41]	validation_0-rmse:0.00382	validation_1-rmse:0.04504
# [42]	validation_0-rmse:0.00353	validation_1-rmse:0.04506
# [43]	validation_0-rmse:0.00330	validation_1-rmse:0.04509
# [44]	validation_0-rmse:0.00312	validation_1-rmse:0.04508
# [45]	validation_0-rmse:0.00296	validation_1-rmse:0.04536
# [46]	validation_0-rmse:0.00278	validation_1-rmse:0.04536
# [47]	validation_0-rmse:0.00272	validation_1-rmse:0.04535
# [48]	validation_0-rmse:0.00264	validation_1-rmse:0.04539
# [49]	validation_0-rmse:0.00248	validation_1-rmse:0.04539
# [50]	validation_0-rmse:0.00240	validation_1-rmse:0.04541
# [51]	validation_0-rmse:0.00218	validation_1-rmse:0.04541
# [52]	validation_0-rmse:0.00212	validation_1-rmse:0.04542
# [53]	validation_0-rmse:0.00198	validation_1-rmse:0.04548
# [54]	validation_0-rmse:0.00190	validation_1-rmse:0.04548
# [55]	validation_0-rmse:0.00185	validation_1-rmse:0.04560
# [56]	validation_0-rmse:0.00180	validation_1-rmse:0.04560
# [57]	validation_0-rmse:0.00173	validation_1-rmse:0.04560
# [58]	validation_0-rmse:0.00170	validation_1-rmse:0.04574
# [59]	validation_0-rmse:0.00159	validation_1-rmse:0.04575
# [60]	validation_0-rmse:0.00152	validation_1-rmse:0.04577
# [61]	validation_0-rmse:0.00139	validation_1-rmse:0.04576
# [62]	validation_0-rmse:0.00127	validation_1-rmse:0.04576
# [63]	validation_0-rmse:0.00121	validation_1-rmse:0.04575
# [64]	validation_0-rmse:0.00112	validation_1-rmse:0.04576
# [65]	validation_0-rmse:0.00104	validation_1-rmse:0.04581
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:835: UserWarning:
#
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
# "\nXGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,\n       colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,\n       importance_type='gain', interaction_constraints=None,\n       learning_rate=0.300000012, max_delta_step=0, max_depth=6,\n       min_child_weight=1, missing=nan, monotone_constraints=None,\n       n_estimators=100, n_jobs=0, num_parallel_tree=1,\n       objective='reg:squarederror', random_state=0, reg_alpha=0,\n       reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,\n       validate_parameters=False, verbosity=None)\n"

# %%
_ = xgb.plot_importance(reg, height=0.9, max_num_features = 10)

# %%
forecast = reg.predict(X_test)
print(forecast)
print(test_values)
# Out:
# [7.167334  7.167334  7.167334  7.107749  7.0546527 7.048011  7.047294 ]
# 359    7.182359
# 360    7.161445
# 361    7.105261
# 362    7.072514
# 363    7.079540
# 364    7.070880
# 365    7.082795
# Name: target_value, dtype: float64

# %%
train.target_value = np.expm1(train.target_value)
forecast = np.expm1(forecast)
test_values = np.expm1(test_values)
show_forecast_test_plot(time, train.target_value, forecast, test_values)
# Out:
# <div>                            <div id="25b0b867-a1ef-43fb-a8ff-afa388bfa8aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25b0b867-a1ef-43fb-a8ff-afa388bfa8aa")) {                    Plotly.newPlot(                        "25b0b867-a1ef-43fb-a8ff-afa388bfa8aa",                        [{"x":["2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-24T00:00:00","2021-12-25T00:00:00","2021-12-26T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-09T00:00:00","2022-04-10T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-16T00:00:00","2022-04-17T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-23T00:00:00","2022-04-24T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-15T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-21T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05- ...
