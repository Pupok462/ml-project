# %%
from src.my_regressions import my_prophet, my_xgboost, my_lgbm, my_arima
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from src.drawing import show_forecast_test_plot, show_time_series_only, show_acf_pacf


#ts = pd.read_csv('train.csv')
ts = pd.read_csv('train_btc.csv')
ts['Date'] = pd.to_datetime(ts['Date'])


time = ts.Date
target = ts.target_value
TRAIN_SIZE = len(target) - 17*7
train, test = train_test_split(ts, train_size=TRAIN_SIZE, shuffle=False)
test_values = target[TRAIN_SIZE:]

# %%
from pmdarima import auto_arima

#df = pd.read_csv('train.csv')
df = pd.read_csv('train_btc.csv')
forecast_arima = my_arima(df, TRAIN_SIZE)
show_forecast_test_plot(time, train.target_value, forecast_arima, test_values)
# Out:
# <div>                            <div id="3c091b0b-5ad7-4d30-8eaf-ffe74d844453" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c091b0b-5ad7-4d30-8eaf-ffe74d844453")) {                    Plotly.newPlot(                        "3c091b0b-5ad7-4d30-8eaf-ffe74d844453",                        [{"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00"
# ...

# %%
forecast_prophet = my_prophet(ts.copy(), TRAIN_SIZE)

show_forecast_test_plot(time, train.target_value, forecast_prophet, test_values)
# Out:
# 19:38:40 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:40 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:40 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:40 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:41 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:41 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:41 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:41 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:42 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:42 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:42 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:42 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:43 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:43 - cmdstanpy - INFO - Chain [1] start processing
# 19:38:43 - cmdstanpy - INFO - Chain [1] done processing
# 19:38:44 - cmdstanpy - INFO - Chain [1] start processing
# ...

# %%
forecast_xgb = my_xgboost(ts.copy(), TRAIN_SIZE)
show_forecast_test_plot(time, train.target_value, forecast_xgb, test_values)
# Out:
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:835: UserWarning:
#
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:835: UserWarning:
#
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:835: UserWarning:
#
# `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:835: UserWarning:
#
# ...

# %%
forecast_lgbt = my_lgbm(ts.copy(), TRAIN_SIZE)
# show_forecast_test_plot(time, train.target_value, forecast_lgbt, test_values)
show_forecast_test_plot(time, train.target_value, forecast_lgbt, test_values)
# Out:
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:177: UserWarning:
#
# Found `num_boost_round` in params. Will use it instead of argument
#
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:181: UserWarning:
#
# 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:239: UserWarning:
#
# 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#
# C:\Users\Osipov\AppData\Local\Programs\Python\Python310\lib\site-packages\lightgbm\engine.py:177: UserWarning:
#
# Found `num_boost_round` in params. Will use it instead of argument
#
# ...

# %%
# listichek = [forecast_lgbt, forecast_xgb, forecast_prophet, forecast_arima, test_values]
# data = pd.DataFrame(data=listichek,columns=['1', '2', '3', '4', '5', '6', '7'], index=['lgbt', 'xgb', 'prophet', 'arima', 'test'])
# data = data.T
# from sklearn.linear_model import LinearRegression
# #нормализовать, убрать интерсепт?, взять Lasso ли Ridge(!) L2
# for i in range(1, 7):
#     reg = LinearRegression().fit(data.drop(columns=['test'], axis=1)[:i], data.test[:i])
#     pred = reg.predict(data.drop(columns=['test'], axis=1)[i:i+1])
#     print(i, data.test[i], pred, reg.coef_, reg.intercept_)
#
#
# reg = LinearRegression().fit(data.drop(columns=['test'], axis=1)[:-1], data.test[:-1])
# pred = reg.predict(data.drop(columns=['test'], axis=1)[-1:])
# # print(reg.score(data.drop(columns=['test'], axis=1)[:-1], data.test[:-1]))
# # print(reg.coef_)
# from sklearn.metrics import mean_squared_error
# error = mean_squared_error(pred, data.test[-1:])
# data

# %%
dataframe = pd.DataFrame(
    {'lgbt': forecast_lgbt,
     'xgb': forecast_xgb,
     'prophet': forecast_prophet,
     'arima' : forecast_arima,
     'target' : test_values
    })

train_x, test_x, train_y, test_y = train_test_split(dataframe.drop(columns=['target'], axis=1), dataframe.target, test_size=30, shuffle=False)
s = StandardScaler()
train_x_scaled = s.fit_transform(train_x, train_y)
test_x_scaled= s.transform(test_x)

# %%
from sklearn. linear_model import Ridge
from sklearn. linear_model import RidgeCV
from sklearn. model_selection import RepeatedKFold


model = RidgeCV(cv=5)
model.fit(train_x_scaled, train_y)
pred_scaled = model.predict(test_x_scaled)


full_data = list(train.target_value)+list(test.target_value[:-30])
show_forecast_test_plot(time, full_data, pred_scaled, test_y)
# Out:
# <div>                            <div id="26d9155c-02df-42c7-bb1d-fdabf49a2111" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26d9155c-02df-42c7-bb1d-fdabf49a2111")) {                    Plotly.newPlot(                        "26d9155c-02df-42c7-bb1d-fdabf49a2111",                        [{"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-04T00:00:00","2020-01-05T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-11T00:00:00","2020-01-12T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-18T00:00:00","2020-01-19T00:00:00","2020-01-20T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00"
# ...

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

def calc_metrics(x, y):
    return [mean_squared_error(x, y), mean_absolute_error(x, y), mean_absolute_percentage_error(x, y)]

errors_frame = pd.DataFrame(columns=['mse', 'mae', 'mape'], index=['final', 'lgbm', 'xgb', 'arima', 'prophet'])
# errors_frame.append(calc_metrics(test_y, pred_scaled), ignore_index=True)
# errors_frame.append(calc_metrics(forecast_lgbt, test_values))
errors_frame.loc['final'] = calc_metrics(test_y, pred_scaled)
errors_frame.loc['lgbm'] = calc_metrics(test_values[-30:], forecast_lgbt[-30:])
errors_frame.loc['xgb'] = calc_metrics(test_values[-30:], forecast_xgb[-30:])
errors_frame.loc['arima'] = calc_metrics(test_values[-30:], forecast_arima[-30:])
errors_frame.loc['prophet'] = calc_metrics(test_values[-30:], forecast_prophet[-30:])

print(model.coef_, model.intercept_)
# Out:
# [2193.48655896  255.58744484  224.40294988  -69.31824396] 24515.72146026966
